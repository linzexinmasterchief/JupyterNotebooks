# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
sns.set_style("whitegrid")

# %%
# set pic size
plt.figure(figsize=(14,8),dpi=80)
# set the vertical distance between value tag and column
column_tag_h = 0.05

# set the amount of data
n = 12

# generate an np array of [0,1,2,...,n]
X = np.arange(n)

# generate upper column heights
Y1 = (X / float(n) + 0.1) * np.random.uniform(0.5, 1.0, n)
# generate upper column heights
Y2 = -((X / float(n) + 0.1) * np.random.uniform(0.5, 1.0, n))

# draw all bars
upper_column = plt.bar(X, Y1, facecolor='#00a0a0', edgecolor='black')
lower_column = plt.bar(X, Y2, facecolor='#a08080', edgecolor='black')

# zip(X, Y1) = [(X[0], Y1[0]), (X[1], Y1[1]), ...]
for x, y in zip(X, Y1):
    plt.text(x, y + column_tag_h, '%.2f'%y, ha='center', va='bottom') # ha: horizontal alignment

for x, y in zip(X, Y2):
    plt.text(x, y - column_tag_h, '%.2f'%y, ha='center', va='top') # ha: horizontal alignment

# set the display range of x and y
plt.xlim(-0.5, 11.5)
plt.ylim(-1.1,1.1)

# set legend (right top corner by default)
plt.legend([upper_column, lower_column], ["upper_column", "lower_column"])

# use x_arr to store the x scale
x_arr = []
# use large range in order to generate decimals
for i in range(-5, 120):
    # only use 0.5, 1, 1.5 ...
    if i % 5 == 0:
        # insert a new value to x_arr
        x_arr.append(i / 10)

# use y_arr to store the y scale
y_arr = []
for i in range(-10, 11):
    # insert a new value to x_arr
    y_arr.append(i / 10)

# use x_arr as x scale
plt.xticks(x_arr)
# use y_arr as y scale
plt.yticks(y_arr)

# display image
plt.show()

# %%
df = pd.DataFrame(np.random.rand(20, 4), columns=['a', 'b', 'c', 'd'])

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x21148dbd748>,
#  <matplotlib.lines.Line2D at 0x21148dbd8d0>,
#  <matplotlib.lines.Line2D at 0x21148dbda58>,
#  <matplotlib.lines.Line2D at 0x21148dbdbe0>]

# %%
df.plot.density();

# %%
sns.set_style("whitegrid")
sns.kdeplot(df["a"], shade=True, color="r")
sns.kdeplot(df["b"], shade=True, color="b")

# %%
def func(i):
#     i = i / 100
    return i**(1/3) - i**(3/2)

# arr = np.fromfunction(func, (100,))
arr = []
for i in range(0,100,1):
    arr.append(func(i / 100))

plt.plot(arr, "g-")

# %%
sns.kdeplot(df["b"], shade=True, color="b")

# %%
sns.distplot(df["a"], kde = False, rug = False)
# Out:
# D:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(df, vars=['a', 'b','c','d'], palette='husl')

# %%
plt.style.use({'figure.figsize':(12, 8)})
sns.factorplot(data=df, x="a", y="b",kind="bar")

# %%
sns.factorplot(data=df, x="a", y="b")

# %%
sns.barplot(x="a", y="b", data=df)

# %%
sns.barplot(x="a", y="b", hue="c", data=df)

# %%
# g = sns.FacetGrid(df, col="a")
# g.map(sns.distplot, "b")

# %%
# g = sns.FacetGrid(df, col="origin")
# g.map(plt.scatter, "horsepower", "mpg")

# %%
# df['tons'] = (df.weight/2000).astype(int)
# g = sns.FacetGrid(df, col="origin", row="tons")
# g.map(sns.kdeplot, "horsepower", "mpg")
# plt.xlim(0, 250)
# plt.ylim(0, 60)
