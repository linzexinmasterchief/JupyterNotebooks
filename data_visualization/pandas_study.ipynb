# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.576725  0.919350  0.205555  0.550695
# 1  0.568084  0.958371  0.731775  0.055874
# 2  0.302911  0.314846  0.634087  0.239061
# 3  0.532391  0.992041  0.902972  0.665574
# 4  0.072531  0.571163  0.757654  0.208252

# %%
df.plot.kde();

# %%
df.plot.bar();

# %%
df.plot.bar(stacked=True);

# %%
df.plot.area();

# %%
df.plot.box();

# %%
df.plot.density();

# %%
df.plot.hist();

# %%
df.plot.line();

# %%
df.plot.scatter(3,1);

# %%
subplots = True
plt.axis('equal')
df["a"].plot.pie();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4c94adf9b3e6> in <module>()
#       1 subplots = True
# ----> 2 plt.axis('equal')
#       3 df["a"].plot.pie();
#
# NameError: name 'plt' is not defined

# %%
df.plot.dist()
