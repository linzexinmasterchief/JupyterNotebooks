# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.622728  0.736318  0.086411  0.037003
# 1  0.977794  0.200438  0.339080  0.821640
# 2  0.526402  0.085325  0.074971  0.143497
# 3  0.280969  0.116830  0.671751  0.035392
# 4  0.440229  0.455090  0.003292  0.627729

# %%
df.plot.kde();

# %%
df.plot.bar();

# %%
df.plot.bar(stacked=True);

# %%
df.plot.area();

# %%
df.plot.box();

# %%
df.plot.density();

# %%
df.plot.hist();

# %%
df.plot.line();

# %%
df.plot.scatter(3,1);

# %%
subplots = True
plt.axis('equal')
df["a"].plot.pie();

# %%
df.plot.dist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-75308a549e14> in <module>()
# ----> 1 df.plot.dist()
#
# AttributeError: 'FramePlotMethods' object has no attribute 'dist'
